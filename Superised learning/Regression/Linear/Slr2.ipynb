# %%
# Implimentation of linear regression without sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("D:\\github-d\\AI-ML\\Datasets\\advertising.csv")

X=df.iloc[:,0]
y=df.iloc[:,1]
X,y
# Out:
# (0     230.1
#  1      44.5
#  2      17.2
#  3     151.5
#  4     180.8
#        ...
#  68    237.4
#  69    216.8
#  70    199.1
#  71    109.8
#  72     26.8
#  Name: TV, Length: 73, dtype: float64,
#  0     22.1
#  1     10.4
#  2     12.0
#  3     16.5
#  4     17.9
#        ...
#  68    18.9
#  69    22.3
#  70    18.3
#  71    12.4
#  72     8.8
#  Name: Sales, Length: 73, dtype: float64)

# %%
plt.scatter(X,y)
plt.show()

# %%
X_mean = X.mean()
std_X = X.std()
X = (X - X_mean) / std_X

# Standardization for y
y_mean= y.mean()
std_y = y.std()
y = (y - y_mean) / std_y

X,y
# Out:
# (0     0.898466
#  1    -1.248018
#  2    -1.563745
#  3    -0.010551
#  4     0.328306
#          ...
#  68    0.982891
#  69    0.744650
#  70    0.539948
#  71   -0.492816
#  72   -1.452720
#  Name: TV, Length: 73, dtype: float64,
#  0     1.252362
#  1    -1.021054
#  2    -0.710160
#  3     0.164231
#  4     0.436264
#          ...
#  68    0.630573
#  69    1.291224
#  70    0.513987
#  71   -0.632436
#  72   -1.331949
#  Name: Sales, Length: 73, dtype: float64)

# %%
X,y
m=0
c=0
lr=0.1
iter=1000

for i in range(iter):
    y_pred=m*X+c
    dm=(-2/len(X))* sum(X*(y-y_pred))
    dc=(-2/len(X))*sum(y-y_pred)
    m-=lr*dm
    c-=lr*dc

print(m,c)
# Out:
# 0.9025762402630839 -3.3337107807923664e-16

# %%
plt.scatter(X,y)
plt.plot(X,y_pred,c="red")
plt.show()

# %%
nm=0
Y_mean=y.mean()
dn=0
for i in range(len(X)):
    nm+=(y_pred[i]-y[i])**2
    dn+=(y[i]-y_mean)**2
    
rs=1-(nm/dn)

print(rs)
# Out:
# 0.99925701931225
