# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("D:\github-d\AI-ML\Datasets\house_price.xlsx")
print(data)
# Out:
#    size  bedroom   price
# 0  2104        3  399900
# 1  1600        3  329900
# 2  2400        3  369000
# 3  1416        2  232000
# 4  3000        4  539900
# 5  2050        5  328800

# %%
# Extract the features and target variable
X = data[['size', 'bedroom']].values
y = data['price'].values

# Feature scaling
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X = (X - X_mean) / X_std

print(X)
# Out:
# [[ 0.01731932 -0.35355339]
#  [-0.95256268 -0.35355339]
#  [ 0.58693256 -0.35355339]
#  [-1.30664658 -1.41421356]
#  [ 1.74155399  0.70710678]
#  [-0.08659661  1.76776695]]

# %%
# Initialize parameters
w = np.zeros(X.shape[1])  # Weights
b = 0  # Bias
learning_rate = 0.01
num_epochs = 1000

# %%
# Define the cost function
def cost_function(X, y, w, b):
    m = len(y)
    predictions = X.dot(w) + b
    cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return cost

# Gradient Descent
cost_history = []

for epoch in range(num_epochs):
    # Calculate and store cost
    cost = cost_function(X, y, w, b)
    cost_history.append(cost)
    
    predictions = X.dot(w) + b
    error = predictions - y
    
    # Calculate gradients
    grad_w = (-2 / len(X)) * np.dot(X.T, error)
    grad_b = (-2 / len(X)) * np.sum(error)
    
    # Update parameters
    w -= learning_rate * grad_w
    b -= learning_rate * grad_b

 
print(f'MSE = {cost}')
    # if (epoch % 100 == 0):
        # print(f'Epoch {epoch}: Cost = {cost}')
# Out:
# MSE = 1.6490510307957961e+35

# %%
# Plot the cost history
plt.plot(range(num_epochs), cost_history)
plt.xlabel('Epoch')
plt.ylabel('Cost')
plt.title('Cost vs. Epoch')
plt.show()
